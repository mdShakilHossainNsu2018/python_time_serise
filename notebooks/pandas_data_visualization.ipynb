# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data/df1.csv')
df2 = pd.read_csv('../data/df2.csv')
df3 = pd.read_csv('../data/df3.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(edgecolor='k', bins=80).autoscale(axis='both', enable=True)

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df2.plot.bar()
df2.plot.bar(stacked=True)

# %%
df2.plot.line(y='a', figsize=(10,4), lw=4)

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*50, alpha=.2)
# Out:
# C:\Users\shaki\Anaconda3\envs\python_time_serise\lib\site-packages\matplotlib\collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap='coolwarm', s=df1['C']*50, alpha=.2)
# Out:
# C:\Users\shaki\Anaconda3\envs\python_time_serise\lib\site-packages\matplotlib\collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()
